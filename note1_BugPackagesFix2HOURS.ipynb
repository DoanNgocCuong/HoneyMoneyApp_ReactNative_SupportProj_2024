# %% [markdown]
# tóm lại là xóa yarn.lock và nodemodules
# 1. Cài npm insatll hoặc ...
# 2. Chạy lệnh expo start -c
# 3. Khắc phục nếu xung đột phiên bản ...

# %% [markdown]
# # Khắc phục phiên bản
# - ko được. => Đành `yarn install` do bên WebStorm đề xuất
# - Sau đó run `expo start -c` được nhưng ko chạy được bản web.
# 1. Khắc phục từng phiên bản ko được
# 2. Update full phiên bản ko được.
#
# => bất lực
#
# hoặc dùng lệnh npm install vượt
# ```bash
# npm install --legacy-peer-deps
# ```
#
# Tuy nhiên rủi ro lúc run ứng dụng.

# %% [markdown]
# To update all your dependencies in `package.json` to their latest versions, you can modify the version numbers to use the caret (`^`) symbol, which allows for minor and patch updates. Here’s how you can update your `package.json`:
#
# ```json:package.json
# {
#   "main": "node_modules/expo/AppEntry.js",
#   "scripts": {
#     "start": "expo start",
#     "android": "expo start --android",
#     "ios": "expo start --ios",
#     "web": "expo start --web",
#     "eject": "expo eject"
#   },
#   "dependencies": {
#     "@firebase/app": "^0.6.17",
#     "@react-native-community/art": "^1.2.0",
#     "@react-native-community/datetimepicker": "^3.4.3",
#     "@react-native-community/masked-view": "^0.1.10",
#     "@react-native-firebase/app": "^11.2.0",
#     "@react-native-firebase/auth": "^11.2.0",
#     "@react-navigation/bottom-tabs": "^5.11.8",
#     "@react-navigation/native": "^5.9.3",
#     "@react-navigation/stack": "^5.14.3",
#     "expo": "^48.0.0", // Update to the latest version
#     "expo-ads-admob": "^10.0.4",
#     "expo-notifications": "^0.18.0", // Update to the latest version
#     "expo-permissions": "^13.0.0", // Update to the latest version
#     "expo-status-bar": "~1.0.3",
#     "firebase": "^9.0.0", // Update to the latest version
#     "react": "^18.0.0", // Update to the latest version
#     "react-dom": "^18.0.0", // Update to the latest version
#     "react-firebase-hooks": "^3.0.3",
#     "react-native": "https://github.com/expo/react-native/archive/sdk-48.0.0.tar.gz", // Update to the latest version
#     "react-native-chart-kit": "^6.11.0",
#     "react-native-circular-action-menu": "^0.5.0",
#     "react-native-currency-input": "^0.1.3",
#     "react-native-datepicker": "^1.7.2",
#     "react-native-elements": "^3.3.2",
#     "react-native-gesture-handler": "^2.0.0", // Update to the latest version
#     "react-native-modal-datetime-picker": "^9.2.0",
#     "react-native-paper": "^4.7.2",
#     "react-native-progress": "^4.1.2",
#     "react-native-reanimated": "^2.0.1",
#     "react-native-safe-area-context": "^3.2.0",
#     "react-native-screens": "^2.18.1",
#     "react-native-svg": "^12.1.0",
#     "react-native-svg-charts": "^5.4.0",
#     "react-native-swipeout": "^2.3.6",
#     "react-native-text-ticker": "^1.12.0",
#     "react-native-web": "^0.18.0", // Update to the latest version
#     "react-navigation": "^4.4.4",
#     "react-redux": "^7.2.3",
#     "redux": "^4.0.5",
#     "victory-native": "^35.3.1"
#   },
#   "devDependencies": {
#     "@babel/core": "^7.9.0"
#   },
#   "private": true
# }
# ```
#
# ### Steps to Update:
# 1. Replace the version numbers in your `package.json` as shown above.
# 2. Run the following command to install the updated dependencies:
#
# ```bash
# npm install
# ```
#
# ### Note:
# - Make sure to check the compatibility of your code with the new versions, as major updates may introduce breaking changes.
# - You can also use tools like `npm-check-updates` to automate this process.
